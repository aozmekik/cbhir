# %%
from utils import *

# %%
def create_model():
    num_classes = 4

    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu',
                            input_shape=(63, 63, 119)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(num_classes))
    model.summary()
    return model

# %%
def train_model(model, X_train, Y_train, X_val, Y_val):
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(
                      from_logits=True),
                  metrics=['accuracy'])

    history = model.fit(X_train, Y_train, epochs=30,
                        validation_data=(X_val, Y_val))
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0.5, 1])
    plt.legend(loc='lower right')

# %%
X, Y, _, _ = get_hsi()
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=42)
X_train.shape, Y_train.shape
# Out:
# ((172, 63, 63, 119), (172,))

# %%
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5)
X_test.shape, Y_test.shape
# Out:
# ((22, 63, 63, 119), (22,))

# %%
X_val.shape, Y_val.shape
# Out:
# ((22, 63, 63, 119), (22,))

# %%
show_img(X_train, Y_train)

# %%
model = create_model()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 61, 61, 32)        34304
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                589888
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 679,876
# Trainable params: 679,876
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_model(model, X_train, Y_train, X_val, Y_val)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 3s 431ms/step - loss: 1.6459 - accuracy: 0.5581 - val_loss: 1.0866 - val_accuracy: 0.6364
# Epoch 2/30
# 6/6 [==============================] - 2s 406ms/step - loss: 0.7534 - accuracy: 0.6337 - val_loss: 0.6142 - val_accuracy: 0.7727
# Epoch 3/30
# 6/6 [==============================] - 3s 422ms/step - loss: 0.6326 - accuracy: 0.7384 - val_loss: 0.5832 - val_accuracy: 0.8182
# Epoch 4/30
# 6/6 [==============================] - 2s 414ms/step - loss: 0.5995 - accuracy: 0.7674 - val_loss: 0.5769 - val_accuracy: 0.8182
# Epoch 5/30
# 6/6 [==============================] - 2s 404ms/step - loss: 0.5351 - accuracy: 0.7674 - val_loss: 0.5842 - val_accuracy: 0.6818
# Epoch 6/30
# 6/6 [==============================] - 2s 412ms/step - loss: 0.5053 - accuracy: 0.7733 - val_loss: 0.4547 - val_accuracy: 0.8182
# Epoch 7/30
# 6/6 [==============================] - 3s 469ms/step - loss: 0.4951 - accuracy: 0.7733 - val_loss: 0.7920 - val_accuracy: 0.7727
# Epoch 8/30
# 6/6 [==============================] - 2s 404ms/step - loss: 0.6785 - accuracy: 0.6744 - val_loss: 0.5643 - val_accuracy: 0.7727
# Epoch 9/30
# 6/6 [==============================] - 3s 438ms/step - loss: 0.4893 - accuracy: 0.8198 - val_loss: 0.4244 - val_accuracy: 0.9091
# Epoch 10/30
# 6/6 [==============================] - 2s 403ms/step - loss: 0.4938 - accuracy: 0.7791 - val_loss: 0.5099 - val_accuracy: 0.7727
# Epoch 11/30
# 6/6 [==============================] - 3s 421ms/step - loss: 0.4814 - accuracy: 0.8023 - val_loss: 0.5124 - val_accuracy: 0.7727
# Epoch 12/30
# 6/6 [==============================] - 3s 435ms/step - loss: 0.4261 - accuracy: 0.8256 - val_loss: 0.4712 - val_accuracy: 0.7273
# Epoch 13/30
# 6/6 [==============================] - 2s 413ms/step - loss: 0.3825 - accuracy: 0.8779 - val_loss: 0.4557 - val_accuracy: 0.8182
# Epoch 14/30
# 6/6 [==============================] - 3s 428ms/step - loss: 0.3562 - accuracy: 0.8721 - val_loss: 0.4718 - val_accuracy: 0.8182
# Epoch 15/30
# 6/6 [==============================] - 3s 511ms/step - loss: 0.3104 - accuracy: 0.9012 - val_loss: 0.5285 - val_accuracy: 0.7727
# Epoch 16/30
# 6/6 [==============================] - 3s 427ms/step - loss: 0.3305 - accuracy: 0.8837 - val_loss: 0.6514 - val_accuracy: 0.7273
# Epoch 17/30
# 6/6 [==============================] - 3s 545ms/step - loss: 0.3197 - accuracy: 0.8779 - val_loss: 0.6353 - val_accuracy: 0.6818
# Epoch 18/30
# 6/6 [==============================] - 3s 444ms/step - loss: 0.3380 - accuracy: 0.8721 - val_loss: 0.7267 - val_accuracy: 0.6818
# Epoch 19/30
# 6/6 [==============================] - 2s 408ms/step - loss: 0.3076 - accuracy: 0.9070 - val_loss: 0.4227 - val_accuracy: 0.7727
# Epoch 20/30
# 6/6 [==============================] - 3s 426ms/step - loss: 0.3024 - accuracy: 0.8953 - val_loss: 0.4690 - val_accuracy: 0.8182
# Epoch 21/30
# 6/6 [==============================] - 3s 419ms/step - loss: 0.2528 - accuracy: 0.8779 - val_loss: 0.6144 - val_accuracy: 0.7727
# Epoch 22/30
# 6/6 [==============================] - 2s 404ms/step - loss: 0.2593 - accuracy: 0.9070 - val_loss: 0.5656 - val_accuracy: 0.7727
# Epoch 23/30
# 6/6 [==============================] - 3s 420ms/step - loss: 0.1958 - accuracy: 0.9419 - val_loss: 0.5951 - val_accuracy: 0.7273
# Epoch 24/30
# 6/6 [==============================] - 2s 403ms/step - loss: 0.1869 - accuracy: 0.9244 - val_loss: 0.6850 - val_accuracy: 0.7273
# Epoch 25/30
# 6/6 [==============================] - 2s 407ms/step - loss: 0.1617 - accuracy: 0.9593 - val_loss: 0.6611 - val_accuracy: 0.7727
# Epoch 26/30
# 6/6 [==============================] - 2s 407ms/step - loss: 0.1472 - accuracy: 0.9477 - val_loss: 0.6503 - val_accuracy: 0.8182
# Epoch 27/30
# 6/6 [==============================] - 2s 409ms/step - loss: 0.1484 - accuracy: 0.9535 - val_loss: 0.6814 - val_accuracy: 0.7727
# Epoch 28/30
# 6/6 [==============================] - 2s 409ms/step - loss: 0.1583 - accuracy: 0.9360 - val_loss: 0.7616 - val_accuracy: 0.8182
# Epoch 29/30
# 6/6 [==============================] - 3s 425ms/step - loss: 0.3097 - accuracy: 0.8721 - val_loss: 1.0482 - val_accuracy: 0.7727
# Epoch 30/30
# 6/6 [==============================] - 2s 391ms/step - loss: 0.3159 - accuracy: 0.8721 - val_loss: 0.6075 - val_accuracy: 0.7727

# %%
test_loss, test_acc = model.evaluate(X_test,  Y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.6402 - accuracy: 0.7273

# %%
model.save('cnn_model')
# Out:
# INFO:tensorflow:Assets written to: cnn_model/assets
